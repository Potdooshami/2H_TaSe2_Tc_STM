# %%
import os
new_directory = '../' 
os.chdir(new_directory)

from gen_img4pub import (
    imgen
)
# Out:
# imagingPhase package loaded
# 0
# phase uploaded
# phase calculated
# 1
# phase uploaded
# phase calculated
# 2
# phase uploaded
# phase calculated
# 3
# phase uploaded
# phase calculated
# 4
# phase uploaded
# phase calculated

# %%
# %matplotlib qt
imgen.dw(0)

# %% [markdown]
# from useful import CropWindow

# %%
import useful
reload(useful)
import matplotlib.pyplot as plt
cw = useful.CropWindow

dw_r = (1142,1496)
dw_g= (1708,202)
dw_b = (1352,173)
dws = [dw_r,dw_g,dw_b]
cw_inst = cw()
cw_inst.set_by_anchor(dw_r,100,'center')
imgen.dw(0)
ax = plt.gca()
fig = plt.gcf()
cw_inst.ax_cropbox(ax)
plt.show()
# Out:
# (1142, 1496)
# 100
# [0.5 0.5]

# %%
import numpy as np
np.array(100) + np.array((0,0))
# Out:
# array([100, 100])

# %%
import numpy as np
q = np.zeros((2,2))

# %%
q
# Out:
# array([[0., 0.],
#        [0., 0.]])

# %%
q[[0]]
# Out:
# array([[0., 0.]])
