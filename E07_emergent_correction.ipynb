# %%
from crypy_examples.dwn_toon import cry_dw_dv
import copy
cry = copy.deepcopy(cry_dw_dv)
cry._basis._artist_list[3]['v_a12'],cry._basis._artist_list[4]['v_a12']=cry._basis._artist_list[4]['v_a12'],cry._basis._artist_list[3]['v_a12']

# %%
fig,ax = cry.plot_crystal()
ax.set_xlim(-2,2)
ax.set_ylim(-2,2)
# Out:
# (-2.0, 2.0)

# %%
fig.savefig('assets/E07.svg')
